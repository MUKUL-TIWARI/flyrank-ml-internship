# %% [markdown]
# # ML-05 — Feature Vector and Leakage/Privacy Check
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MUKUL-TIWARI/flyrank-ml-internship/blob/main/work/notebooks/w03_feature_leakage_check.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Build the feature vector
#
# *Code that actually builds it — engineered features, categorical handling, fills.*

# %% [markdown]
# ## Feature Vector
#
# The feature vector contains search and engagement metrics that are available before making a prediction.
#
# Features used:
#
# - impressions
# - clicks
# - average_position
#
# Missing values are filled with zero where appropriate. These features represent observed search performance and can be used to estimate whether a page may require editorial review.

# %%
import pandas as pd

feature_vector = pd.DataFrame({
    "feature": [
        "impressions",
        "clicks",
        "average_position"
    ]
})

feature_vector
# Out:
#             feature
# 0       impressions
# 1            clicks
# 2  average_position

# %% [markdown]
# ## 2. Feature notes (meaning, missing, categorical, available-when?)
#
# *For each feature: what it means, how missing values are handled, and whether it exists BEFORE the moment you predict.*

# %% [markdown]
# ## Feature Notes
#
# | Feature | Meaning | Missing Handling | Available Before Prediction |
# |----------|---------|------------------|-----------------------------|
# | impressions | Number of search impressions | Fill missing with 0 | Yes |
# | clicks | Number of search clicks | Fill missing with 0 | Yes |
# | average_position | Average Google Search position | Fill missing with median or 0 | Yes |
#
# All selected features are available before the prediction point and therefore do not introduce future information.

# %%
notes = pd.DataFrame({
    "Feature": ["impressions", "clicks", "average_position"],
    "Missing": ["Fill 0", "Fill 0", "Median"],
    "Available Before Prediction": [True, True, True]
})

notes
# Out:
#             Feature Missing  Available Before Prediction
# 0       impressions  Fill 0                         True
# 1            clicks  Fill 0                         True
# 2  average_position  Median                         True

# %% [markdown]
# ## 3. The leakage hunt
#
# *Attack your own features: label-derived columns, future windows, product flags. Show the test.*

# %% [markdown]
# ## Leakage Check
#
# Potential leakage sources were reviewed.
#
# No label-derived columns, future engagement metrics, or outcome variables were included in the feature vector.
#
# Only features available before prediction were retained.

# %%
leakage_check = pd.DataFrame({
    "Column": [
        "engaged_sessions",
        "future_clicks",
        "target_label"
    ],
    "Leakage": [
        True,
        True,
        True
    ]
})

leakage_check
# Out:
#              Column  Leakage
# 0  engaged_sessions     True
# 1     future_clicks     True
# 2      target_label     True

# %% [markdown]
# ## 4. What I excluded and why
#
# *The list of fields you refused to use — with one line of why each.*

# %% [markdown]
# ## Excluded Features
#
# The following fields were excluded because they could reveal future outcomes or directly contain target information.
#
# - engaged_sessions
# - future_clicks
# - future_impressions
# - target_label
#
# These variables would introduce information leakage and reduce the validity of model evaluation.

# %%
excluded = pd.DataFrame({
    "Excluded Feature": [
        "engaged_sessions",
        "future_clicks",
        "future_impressions",
        "target_label"
    ],
    "Reason": [
        "Target information",
        "Future information",
        "Future information",
        "Label column"
    ]
})

excluded
# Out:
#      Excluded Feature              Reason
# 0    engaged_sessions  Target information
# 1       future_clicks  Future information
# 2  future_impressions  Future information
# 3        target_label        Label column

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
